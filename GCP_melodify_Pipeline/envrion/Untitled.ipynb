# %% [markdown]
# 도커 빌드 및 푸시, Components 이미지 설정

# %%
# !docker build -t asia-northeast3-docker.pkg.dev/andong-24-team-101/components-image/com-image:latest .
# !docker push asia-northeast3-docker.pkg.dev/andong-24-team-101/components-image/com-image:latest
# Out:
# Sending build context to Docker daemon  23.04kB
# Step 1/10 : FROM nvidia/cuda:11.8.0-cudnn8-runtime-ubuntu20.04
# 11.8.0-cudnn8-runtime-ubuntu20.04: Pulling from nvidia/cuda
#
# 4c3075c9: Pulling fs layer
# 15c238d7: Pulling fs layer
# e2e61518: Pulling fs layer
# 6248e682: Pulling fs layer
# b7817039: Pulling fs layer
# 90485347: Pulling fs layer
# 245097e4: Pulling fs layer
# d7e9912b: Pulling fs layer
# 8f745445: Pulling fs layer
# Digest: sha256:c2336dadc71ae5b5ce490a55cc0100d876287d28f429a5d2840c8a3a8e86fef0[2K
# Status: Downloaded newer image for nvidia/cuda:11.8.0-cudnn8-runtime-ubuntu20.04
#  ---> 46d26ec802e4
# Step 2/10 : RUN apt-get update && apt-get install -y software-properties-common     && add-apt-repository ppa:deadsnakes/ppa     && apt-get update && apt-get install -y python3.9 python3.9-distutils python3.9-venv     && apt-get install -y python3-pip
#  ---> Running in adbd4c587254
# ...
